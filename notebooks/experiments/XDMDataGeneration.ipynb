# %% [markdown]
# # XDM Event Creation
#
# This section creates random XDM data according to a (fairly) arbitrary schema
#
# There are a few hacks and shortcomings right now:
# - Lists aren't created properly
# - I ignore a few XDM fields where a regex pattern is specified

# %%
import random, string
import uuid
from datetime import datetime, timedelta
import mmh3
import rstr
from random import randrange

def random_date(start, end):
    """
    This function will return a random datetime between two datetime 
    objects.
    """
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

def normalize_ecid(ecid_part):
    ecid_part_str = str(abs(ecid_part))
    if len(ecid_part_str) != 19:
        ecid_part_str = "".join([str(x) for x in range(
            0, 19 - len(ecid_part_str))]) + ecid_part_str
    return ecid_part_str


def get_ecid(email):
    """
    The ECID must be two valid 19 digit longs concatenated together
    """
    ecidpart1, ecidpart2 = mmh3.hash64(email)
    ecid1, ecid2 = (normalize_ecid(ecidpart1), normalize_ecid(ecidpart2))
    return ecid1 + ecid2


def create_string_value(props):
    if "format" in props:
        if props["format"] == "uri-reference":
            return str(uuid.uuid4())
        elif props["format"] == "uri":
            return f"https://www.{''.join(random.choices(string.ascii_letters + string.digits, k=10))}.com"
    elif "examples" in props:
        return random.choice([eg for eg in props["examples"]])
    elif "pattern" in props:
        return rstr.xeger(props["pattern"])
    elif "meta:enum" in props:
        return random.choice([enum for enum in props["meta:enum"].keys()])
    elif "enum" in props:
        return random.choice(props["enum"])
    else:
        nchars = random.randint(2,10)
        return ''.join(random.choices(string.ascii_letters + string.digits, k=nchars))

def create_identity_map(email=None):
    nchars = random.randint(2,10)
    if email is None:
        email = ''.join(random.choices(string.ascii_letters + string.digits, k=nchars)) + "@adobe.com"
    ecid = get_ecid(email)        
    return {
            "ECID": [
                {
                    "id": f"{ecid}",
                    "primary": True
                }
            ],
            "email": [
                {
                    "id": f"{email}",
                    "primary": True
                }
            ]
        }

def create_map_value(field_name, props):
    if field_name == "identityMap":
        return create_identity_map()
    



def value_creator(xdm_type, field_name, props, start, end):
    match xdm_type:
        case "string":
            return create_string_value(props)
        case "map":
            return create_map_value(field_name, props)
        case "date-time":
            return random_date(start, end).isoformat()
        case "number":
            return random.uniform(0,90)
        case "int":
            return random.randint(0,20)
        case "long":
            return random.randint(2,10000)
        case "boolean":
            return False
        case "array":
            return create_array_values(field_name, props, start, end)
        case "object":
            #this is technically wrong
            return {}

def create_array_values(field_name, props, start, end):

    return [value_creator(props["items"]["meta:xdmType"], field_name, props, start, end)]


def create_or_get_first_element_list_leaf_node(json_tree, node_name):
    list_nodes = [node_name.partition(node)[0] for node in node_name.split("/") if node.endswith("[]{}")]
    
    
def descend_dict_tree(base_dict, node_path, from_end=0):
    node = base_dict
    node_path_list = node_path.split("/")
    for node_name in node_path_list[:len(node_path_list)-from_end]:
        node = node[node_name]
        
    return node

        
def change_key(d, path_to_value, new_value):
    for key in path_to_value[:-1]:
        d = d[key]
    d[path_to_value[-1]] = new_value
    
    
def copy_dict_tree(base_dict, source_node_path, target_node_path):
    source_node = descend_dict_tree(base_dict, source_node_path)
    
    change_key(base_dict, target_node_path.split("/"), source_node)
    
    return base_dict
        
        
def create_xdm_event(schema, 
                     user_id=None,
                     event_type=None,
                     overrides=None,
                     duplicates=None,
                     timestamp = None,
                     start_date=datetime.now() - timedelta(days=100), 
                     end_date=datetime.now()):
    """
    schema - a Schema that was grabbed from platform UI's network tab
    user_id - optional string
    event_type - optional string overriding events
    timestamp - optional string overriding timestamps
    duplicates  - List[(String, String)] describing source and target path that should be viewed as duplicates
    overrides - List[(String, Any)] describing target field to be modified, and value that it should take. 
    """
    
    mixins_to_ignore = ["[]{}", "videoSegment", "stateProvince", "currencyCode", "optionContent"]
        
    base_event = {}

    #Create base fields
    for key, value in schema["data"]["schemaComposition"]["schemaClass"]["properties"].items():
        base_event[key] = value_creator(value["meta:xdmType"], key, value, start=start_date, end=end_date)
        

    
    #Create mixins
    for key, value in schema["data"]["schemaComposition"]["schemaMixins"][0]["properties"].items():
        if any(x in key for x in mixins_to_ignore):
            continue

        if "/" in key:
            node = base_event
            for node_name in key.split("/")[:-1]:
                if node_name not in node or node[node_name] is None:
                    node[node_name] = {}
                node = node[node_name]

            node[key.split("/")[-1]] = value_creator(value["meta:xdmType"], key, value,  start=start_date, end=end_date)

        else:

            base_event[key] = value_creator(value["meta:xdmType"], key, value,  start=start_date, end=end_date)

    #overrides of base fields
    if user_id:
        base_event["identityMap"] = create_identity_map(user_id)
    if event_type:
        base_event["eventType"] = event_type 
    if timestamp:
        base_event["timestamp"] = timestamp
    if overrides:
        for path, value in overrides:
            change_key(base_event, path.split("/"), value)
    if duplicates:
        for (source_node_path, target_node_path) in duplicates:
            base_event = copy_dict_tree(base_event, source_node_path, target_node_path)

        
        
    return base_event

# %% [markdown]
# ## Load an arbitrary schema and create event
# Here, we load an arbitrary schema from file and create the random XDM event

# %%
import json

with open("../resources/xdm_schema.json", "r") as f:
    analytics_ee_schema = json.load(f)
    
event = create_xdm_event(analytics_ee_schema)
event
# Out:
# {'_id': '22a2d3cd-3397-4071-a680-0ae965f533c7',
#  'eventMergeId': '4CZ1KV59L',
#  'eventType': 'opportunityEvent.removeFromOpportunity',
#  'identityMap': {'ECID': [{'id': '06242027923987868946752329435998598170',
#     'primary': True}],
#   'email': [{'id': 'otkoIHz@adobe.com', 'primary': True}]},
#  'producedBy': 'system',
#  'timestamp': '2022-10-24T13:25:39.047907',
#  '_experience': {'analytics': {'customDimensions': {'eVars': {'eVar1': 'u2PRu',
#      'eVar10': 'g0w5vvbO',
#      'eVar100': 'A0WlfE7',
#      'eVar101': 'Eh',
#      'eVar102': 'wMMuocvv',
#      'eVar103': 'FLXHz8nm',
#      'eVar104': '3VTGINK',
#      'eVar105': 'UD4WV8',
#      'eVar106': 'Kt8V4',
#      'eVar107': 'SizTi1H',
#      'eVar108': 'DFf2S',
#      'eVar109': 'uzIx',
#      'eVar11': '1K',
#      'eVar110': 'yHfYYdCU',
#      'eVar111': '1pbl',
#      'eVar112': 'NQAIh8gA8',
#      'eVar113': 'S8ni0hpO',
#      'eVar114': '9HON',
#      'eVar115': 'YYGLPF295B',
#      'eVar116': 'uOyJmq',
#      'eVar117': 'xvJ6J6',
#      'eVar118': 'kfJ0',
#      'eVar119': 'DUD',
#      'eVar12': 'cfe',
#      'eVar120': 'zQpjE',
#      'eVar121': 'ml1UqVZZik',
#      'eVar122': 'sQHoPTYjb',
#      'eVar123': 'XHf',
#      'eVar124': 'rtKuyIjMj',
#      'eVar125': 'coAvE',
#      'eVar126': 'BXRdn',
#      'eVar127': 'MviD7x6QAZ',
#      'eVar128': 'h8J',
#      'eVar129': 'goL',
#      'eVar13': '4o14',
#      'eVar130': 'nPwcwzDQr',
#      'eVar131': 'PK8eSyi',
#      'eVar132': '9jFkFo',
#      'eVar133': 'TxVfey',
#      'eVar134': 'o0',
#      'eVar135': 'WotCYZ',
#      'eVar136': 'vTJMi',
#      'eVar137': 'sPJuLGqA4N',
#      'eVar138': 'JalxZ3',
#      'eVar139': '4GxWD',
#      'eVar14': 'M9fS3YZheW',
#      'eVar140': 'YSut',
#      'eVar141': '5Ll1U',
#      'eVar142': 'CiGr46O',
#      'eVar143': 'Ius8JIMHET',
#      'eVar144': 'yBgnQsB5D',
#      'eVar145': '5EWDgU84E',
#      'eVar146': 'E9rPMy',
#      'eVar147': 'yVFEN85GT',
#      'eVar148': 'RMNb',
#      'eVar149': 'F7iXziAWd7',
#      'eVar15': 'tZBKODnVij',
#      'eVar150': '7My',
#      'eVar151': 'gD7IR',
#      'eVar152': 'ZjWbNdNMka',
#      'eVar153': '5XeY84nnO',
#      'eVar154': 'gsVNmuqBbu',
#      'eVar155': 'bcF58',
#      'eVar156': 'z2',
#      'eVar157': 'xyr5PLW',
#      'eVar158': 'mAq',
#      'eVar159': 'T15',
#      'eVar16': 'TcyQ1sykd',
#      'eVar160': 'B35aahC',
#      'eVar161': 'In7',
#      'eVar162': '9oo',
#      'eVar163': 'kHMKiS',
#      'eVar164': 'hgdoU7Bsx',
#      'eVar165': 'Txnd',
#      'eVar166': 'Bmf4DR5H',
#      'eVar167': '2l',
#      'eVar168': 'aoe',
#      'eVar169': 'uZn4T2xkc',
#      'eVar17': 'mnBXc7',
#      'eVar170': 'dQ8X',
#      'eVar171': 'LK1',
#      'eVar172': 'dYKEvHTzLq',
#      'eVar173': 'aZWBsw',
#      'eVar174': 'NnMHwWY',
#      'eVar175': 'EYIr90M',
#      'eVar176': 'YPizN6',
#      'eVar177': 'LfG',
#      'eVar178': 'oJpZT',
#      'eVar179': '61jdvELqz',
#      'eVar18': '3LRb4',
#      'eVar180': 'MacjHmU1Jf',
#      'eVar181': 'tU3JkbV1',
#      'eVar182': 'P7mBP',
#      'eVar183': 'H7e9nRBNB',
#      'eVar184': 'h6WxFPR0m',
#      'eVar185': 'm26x9D',
#      'eVar186': 'wzuN7',
#      'eVar187': 'NLb40fJT3',
#      'eVar188': 'ySQepN',
#      'eVar189': 'Eq0M',
#      'eVar19': 'FBHcQ',
#      'eVar190': 'LSj',
#      'eVar191': 'svOpOr',
#      'eVar192': 'Q53Sm6UaCI',
#      'eVar193': 'AH2PqlW',
#      'eVar194': 'RysG7b',
#      'eVar195': 'Lp2G80U',
#      'eVar196': 't3',
#      'eVar197': 'ys',
#      'eVar198': 'iCaJI60GI',
#      'eVar199': 'H9pj2UnS',
#      'eVar2': 'eu',
#      'eVar20': 'ykS6',
#      'eVar200': 'dVvO7',
#      'eVar201': 'gMJ9kkZKli',
#      'eVar202': 'rNJ8Jr1o',
#      'eVar203': 'B23UUJ7',
#      'eVar204': 'R6Mz',
#      'eVar205': 'xvO4q',
#      'eVar206': 'Apeh8',
#      'eVar207': 'nO3xG8',
#      'eVar208': 'Cc2QvlT',
#      'eVar209': '2Ed',
#      'eVar21': 'BU',
#      'eVar210': 'V5',
#      'eVar211': '77C',
#      'eVar212': 'ZhOC',
#      'eVar213': 'zbBVdt8bX4',
#      'eVar214': 'hAlk7',
#      'eVar215': '7aPMu7PC8',
#      'eVar216': '616N5',
#      'eVar217': '4aFnp3Bab',
#      'eVar218': 'C79S',
#      'eVar219': 'hT3WnxzLB',
#      'eVar22': 'mV',
#      'eVar220': 'x4FWc5',
#      'eVar221': 'DO',
#      'eVar222': 'nx1m4',
#      'eVar223': '1EwOe8nf',
#      'eVar224': '77',
#      'eVar225': 'c6jwMdjXID',
#      'eVar226': 'xd1',
#      'eVar227': 'SWT1TNr30o',
#      'eVar228': 'tMtg6LhhF',
#      'eVar229': 'glxX4iHZl6',
#      'eVar23': 'ZhHu0tZtV',
#      'eVar230': '2g8k',
#      'eVar231': 'jFO0',
#      'eVar232': 'UDG31TypsT',
#      'eVar233': '8r',
#      'eVar234': 'SSoTqzzotk',
#      'eVar235': 'aD',
#      'eVar236': 't3Z64',
#      'eVar237': '8GgE',
#      'eVar238': 'SHJYuFtl6',
#      'eVar239': '0K',
#      'eVar24': 'dLgR',
#      'eVar240': '5EH4I2Esj',
#      'eVar241': 'mfFR',
#      'eVar242': '91Irtm1',
#      'eVar243': 'BvxFU3m',
#      'eVar244': 'x9vKw0',
#      'eVar245': 'FiuLQ57Vn',
#      'eVar246': 'zaECJ',
#      'eVar247': 'ko',
#      'eVar248': 'fxU9EGbi',
#      'eVar249': 'YwOUVA',
#      'eVar25': '19Eto9C',
#      'eVar250': 'ZK52M',
#      'eVar26': 'suZ',
#      'eVar27': 'PkhC',
#      'eVar28': 'wI1QreltX',
#      'eVar29': 'SiK',
#      'eVar3': 'jOCNWfiu',
#      'eVar30': '1nr8N4Hq',
#      'eVar31': 'TR',
#      'eVar32': 'i19MkJHt',
#      'eVar33': '4he0jfdH0e',
#      'eVar34': 'nYby',
#      'eVar35': 'cG6F',
#      'eVar36': 'iEbU',
#      'eVar37': 'OyZ2rQ5dFV',
#      'eVar38': 'elON9pOUNT',
#      'eVar39': 'Kq',
#      'eVar4': 'wgkb',
#      'eVar40': 'BitvAQ',
#      'eVar41': 'Jhi',
#      'eVar42': '5GcmYtOFt',
#      'eVar43': 'Qmy',
#      'eVar44': '4fyNXrDu',
#      'eVar45': 'rxr',
#      'eVar46': 'AHmYst',
#      'eVar47': 'kCgpc4',
#      'eVar48': 'sjxgKVC',
#      'eVar49': 'T0lrOG8nO',
#      'eVar5': 'AhuhLqY1bF',
#      'eVar50': 'KJBHIshA',
#      'eVar51': 'GMPQlrcRa',
#      'eVar52': 'Fmg85dvg4i',
#      'eVar53': 'O5QX',
#      'eVar54': 'FPFrVVxnIc',
#      'eVar55': 'aya',
#      'eVar56': 'nmYFbvGah',
#      'eVar57': 'qHUdQ5X5oi',
#      'eVar58': '7TFwLJ',
#      'eVar59': 'QRcPnAEGiJ',
#      'eVar6': 'nKYb7UD',
#      'eVar60': 'dPhN2xB',
#      'eVar61': 'DcQVW',
#      'eVar62': 'M6n235WY',
#      'eVar63': 'Wnu0W',
#      'eVar64': 'h8',
#      'eVar65': 'NuANy',
#      'eVar66': 'tZmubNknBg',
#      'eVar67': '1rl8RWe1Wa',
#      'eVar68': 'BxS',
#      'eVar69': 'fMn',
#      'eVar7': 'G2LPCUB',
#      'eVar70': 'wFYb',
#      'eVar71': 'wBVYe',
#      'eVar72': 'gX1W',
#      'eVar73': 'DpD7',
#      'eVar74': 'CSxdT8AHQK',
#      'eVar75': 'kQ',
#      'eVar76': 'GjSA1OuQuV',
#      'eVar77': 'LvHK',
#      'eVar78': 'eAyq8',
#      'eVar79': 'OnXOS00Q8X',
#      'eVar8': 'swrugb',
#      'eVar80': 'lE0vTF',
#      'eVar81': 'aZ2AngEkt',
#      'eVar82': 'cMHrtNf',
#      'eVar83': 'OO',
#      'eVar84': 'qCX1nzf',
#      'eVar85': 'zPzBPINgn',
#      'eVar86': 'raxh',
#      'eVar87': '3iCNRJfp',
#      'eVar88': 'OM7yUB3ch',
#      'eVar89': 'AR',
#      'eVar9': 'vfhZ5XS',
#      'eVar90': 'OpNHFk',
#      'eVar91': '7ocMfxot',
#      'eVar92': '4PJPI',
#      'eVar93': 'KHTE',
#      'eVar94': 'cwkI',
#      'eVar95': '9KQeWxv9v',
#      'eVar96': '7EtyHpL9hY',
#      'eVar97': 'XeCFGn95i',
#      'eVar98': 'p5Kc',
#      'eVar99': 'ZempTRP'},
#     'hierarchies': {'hier1': {'delimiter': '5a'},
#      'hier2': {'delimiter': 'y9'},
#      'hier3': {'delimiter': '8SU'},
#      'hier4': {'delimiter': 'OVLOGWKu'},
#      'hier5': {'delimiter': 'FFstv'}},
#     'listProps': {'prop1': {'delimiter': 'x5ed65Mx'},
#      'prop10': {'delimiter': 'q5VhFdt'},
#      'prop11': {'delimiter': 'Dy6ZVFYj'},
#      'prop12': {'delimiter': 'gth5'},
#      'prop13': {'delimiter': 'xG2r6'},
#      'prop14': {'delimiter': '78nrk'},
#      'prop15': {'delimiter': 'tPzN'},
#      'prop16': {'delimiter': '13pciUMPtp'},
#      'prop17': {'delimiter': 'aUjncqKxv5'},
#      'prop18': {'delimiter': 'SRFpLdkGH'},
#      'prop19': {'delimiter': 'y83i'},
#      'prop2': {'delimiter': 't3QhkF0'},
#      'prop20': {'delimiter': 'e4sLb'},
#      'prop21': {'delimiter': 'AeW'},
#      'prop22': {'delimiter': 'Me5qUHVe2'},
#      'prop23': {'delimiter': 'nDt2N'},
#      'prop24': {'delimiter': 'j1FUON'},
#      'prop25': {'delimiter': 'ky8YyVSx'},
#      'prop19': 'Vt5',
#      'prop2': '7jV7Vi7',
#      'prop20': '8rjL9RI6',
#      'prop21': 'GpY1NWo',
#      'prop22': 'Z5zfn',
#      'prop23': 'DZlQv',
#      'prop24': 'IU98U',
#      'prop25': 'jlvtZzyYg',
#      'prop26': 'jsqqp8qo7m',
#      'prop27': 'wxtra3NR',
#      'prop28': 'CMEQEhjOv',
#      'prop29': 'DFAl6',
#      'prop3': '80Cu7',
#      'prop30': 'alOtUD5',
#      'prop31': 'Iu6TsI2CN',
#      'prop32': 'eeKgnIEy',
#      'prop33': '1l',
#      'prop34': 'qaFf',
#      'prop35': '8ni',
#      'prop36': 'TGZnEZeqlq',
#      'prop37': 'XPZlcT9qzF',
#      'prop38': 'I8XkuKRH6',
#      'prop39': 'SYZ3gMj266',
#      'prop4': 'Tv',
#      'prop40': 'NghPODn',
#      'prop41': 'TQW0',
#      'prop42': 'Xyv6',
#      'prop43': 'eJqc',
#      'prop44': '339y5A2r',
#      'prop45': 'yS',
#      'prop46': 'bmJbhJcc1',
#      'prop47': '2HStvA1',
#      'prop48': 'pB4IU5',
#      'prop49': 'sV',
#      'prop5': 'CEoDTOU',
#      'prop50': 'a2',
#      'prop51': 'UzL',
#      'prop52': 'iI',
#      'prop53': 'mDX4X',
#      'prop54': 'mMjDHk',
#      'prop55': 'ug2II',
#      'prop56': 'PmhsXW',
#      'prop57': 'URSEJss3',
#      'prop58': '0sMne',
#      'prop59': 'ct5',
#      'prop6': 'QDt52n',
#      'prop60': 'uSrV7uHBd',
#      'prop61': 'lfROFCjF',
#      'prop62': 'gc',
#      'prop63': 'hYNC',
#      'prop64': '7I',
#      'prop65': 'LvjCzy4s',
#      'prop66': 'X8',
#      'prop67': 'QWklX',
#      'prop68': 'xGxEArv4',
#      'prop69': 'KnaQ5pplqv',
#      'prop7': 'q8BxC',
#      'prop70': 'Llp7Ne2',
#      'prop71': 'oEByyGZ',
#      'prop72': 'TB3',
#      'prop73': '9WJPjs1',
#      'prop74': 'GTy',
#      'prop75': 'zgFZK',
#      'prop8': 'RN3jU',
#      'prop9': 'Eu'}},
#    'endUser': {'firstTimestamp': 507,
#     'firstWeb': {'webInteraction': {'URL': 'kZR',
#       'linkClicks': {'id': 'RIP', 'value': 61.2772636384493},
#       'name': 'K8',
#       'region': '2pq',
#       'type': 'exit'},
#      'webPageDetails': {'URL': 'iiePByuIc',
#       'isErrorPage': False,
#       'isHomePage': False,
#       'name': 'Jt',
#       'pageViews': {'id': 'ijErkh', 'value': 60.70662526283752},
#       'server': '1BHq6vE',
#       'siteSection': 'ZI',
#       'viewName': 'k1'},
#      'webReferrer': {'URL': 'gVar96J', 'type': 'unknown'}}},
#    'environment': {'browserID': 11,
#     'browserIDStr': '5796870761505657303381052589058515399307418274657171929530236092676845112',
#     'operatingSystemID': 11,
#     'operatingSystemIDStr': '08568314793938698473988317801698848002113844'},
#    'event101to200': {'event101': {'id': 'ZB', 'value': 75.71914761766246},
#     'event102': {'id': '7qjm', 'value': 16.079907277726978},
#     'event103': {'id': 'werx', 'value': 2.5889491444887125},
#   'featureUsages': {'id': 'DlaBa', 'value': 16.362026421109746},
#   'firstLaunches': {'id': '10Vr', 'value': 81.02690645568815},
#   'id': 'EucFeB0jHz',
#   'installs': {'id': 'hXAu8', 'value': 3.614904839692578},
#   'isClose': False,
#   'isInstall': False,
#   'isLaunch': False,
#   'isUpgrade': False,
#   'launches': {'id': '34r8hG44', 'value': 89.79941641848778},
#   'name': 'VGT3iWzzX',
#   'sessionLength': 20,
#   'upgrades': {'id': 'pHJge3', 'value': 77.45691884284662},
#   'userPerspective': 'detached',
#   'version': 'k2njRoi0'},
#  'channel': {'_id': 'fb7a02f5-69c7-4862-958a-fac30c728b93',
#   '_type': 'https://www.ukUl485hbB.com',
#   'mediaAction': 'offerOpens',
#   'mediaType': 'owned',
#   'mode': 'pull',
#   'typeAtSource': 'm0D7Dyg'},
#  'commerce': {'cart': {'cartID': '3Jlun', 'cartSource': 'NXjzl'},
#   'cartAbandons': {'id': 'wVttAgo9Bs', 'value': 78.25282041810682},
#   'checkouts': {'id': 'Fg26Qtpsz', 'value': 88.66186472597637},
#   'inStorePurchase': {'id': 'YjTl1Or4', 'value': 40.114889734049},
#   'instantPurchase': {'id': 'FNCjY1', 'value': 2.4296147310612906},
#   'order': {'orderType': 'checkout',
#    'priceTotal': 39.56390526788022,
#    'purchaseID': 'JvpfS5',
#    'purchaseOrderNumber': 'Rqk7TS'},
#   'productListAdds': {'id': 'mbQ2', 'value': 77.70997075917123},
#   'productListOpens': {'id': 'RGRyIr', 'value': 75.79490903282293},
#   'productListRemovals': {'id': 'IJIvCNc0Ox', 'value': 15.439704395238842},
#   'productListReopens': {'id': 'Pq', 'value': 70.07027045020553},
#   'productListViews': {'id': 'iL', 'value': 79.65415978855884},
#   'productViews': {'id': 'mxfvbNz0Qk', 'value': 41.32723395546524},
#   'promotionID': 'ZFEPwGs0',
#   'purchases': {'id': 'O7V', 'value': 36.498093248790326},
#   'saveForLaters': {'id': '5Sjo5aUmRi', 'value': 62.009635409226185},
#   'shipping': {'address': {'_id': 'e8317863-184f-43a6-8423-522c61d8fb68',
#     '_repo': {'createDate': '2022-09-07T16:41:00.047907',
#      'modifyDate': '2022-08-12T03:01:58.047907'},
#     '_schema': {'description': 'JBB',
#      'elevation': 80.17792727199408,
#      'latitude': 46.40648219085028,
#      'longitude': 83.54222158960586},
#     'city': 'LaVgV',
#     'country': 'CUE',
#     'countryCode': 'ZE',
#     'createdByBatchID': 'c9a26f14-d0b0-4800-bd3c-c9fc99f9800d',
#     'dmaID': 7,
#     'label': 'aRpt',
#     'lastVerifiedDate': None,
#     'modifiedByBatchID': '48f28b47-8756-49ac-9b93-902750589210',
#     'msaID': 2,
#     'postOfficeBox': 'suEp1n0',
#     'postalCode': '3hEe',
#     'primary': False,
#     'region': 'k2I',
#     'repositoryCreatedBy': 'xEF',
#     'repositoryLastModifiedBy': 'jKjXrO',
#     'state': 'dxDrd267k',
#     'status': 'pending_verification',
#     'statusReason': 'bOZFcHwHf',
#     'street1': 'sWjn8',
#     'street2': 'q2I7Qrs',
#     'street3': '8hlWnJl',
#     'street4': 'yuptHQE0xG'},
#    'shippingAmount': 55.02752026483281,
#    'shippingDestination': 'home',
#    'shippingMethod': 'my'}},
#  'dataSource': {'_id': '687f83cf-21fd-4797-a8d9-647bbc68c63a',
#   'code': 'yXDFtP5j'},
#  'device': {'colorDepth': 18,
#   'isBackgroundPushEnabled': False,
#   'isLocationEnabled': False,
#   'isPushOptIn': False,
#   'locationPermission': 'ALWAYS_ALLOWED',
#   'manufacturer': 'TBJSHYfkn',
#   'model': '1qtp70EmN3',
#   'modelNumber': 'eB',
#   'screenHeight': 6,
#   'screenOrientation': 'portrait',
#   'screenWidth': 13,
#   'type': 'gaming',
#   'typeID': 'roeB',
#   'typeIDService': 'https://www.QfluUNMnsc.com'},
#  'directMarketing': {'bounces': {'id': '8LaPQ', 'value': 85.68078622539929},
#   'clicks': {'id': 'd5a', 'value': 41.21267366076355},
#   'customActions': {'id': 'CG2c6TfM', 'value': 65.73491585658958},
#   'emailDelivered': {'id': 'jF2yKEK', 'value': 81.90870866115151},
#   'emailVisitorID': 'PRozEZ',
#   'excludes': {'id': 'TeCd2i1y', 'value': 30.02653845996806},
#   'hashedEmail': 'rb7WAZ1Y',
#   'impressions': {'id': 'QUAH5', 'value': 8.327966129604444},
#   'marketingSubscription': {'id': 'YChB', 'value': 3.527054921020496},
#   'messageID': '5ufVcib',
#   'mirrorPages': {'id': 'yqOkbXRn0', 'value': 83.58765215357138},
#   'nonDeliverables': {'id': 'RdVAATbyYG', 'value': 16.22567256502533},
#   'notSent': {'id': 'FfcWr3Qc6', 'value': 86.01863079430439},
#   'offerOpens': {'id': 'eS8isYSv', 'value': 47.9548166968812},
#   'opens': {'id': 'zd5jX5R3q', 'value': 87.81461131954721},
#   'sends': {'id': 'ro211jH', 'value': 31.309594721806928},
#   'unsubscribeReason': 'ZE5sLLw',
#   'unsubscriptions': {'id': 'ycz', 'value': 84.9436262283048},
#   'userComplaints': {'id': '7m43w6zJ', 'value': 43.85182138648385}},
#  'endUserIDs': {'_experience': {'aacustomid': {'authenticatedState': 'loggedOut',
#     'id': 'SMomDkL',
#     'namespace': {'code': 'iYeZCEk'},
#     'primary': False,
#     'xid': '2LoV5au6O'},
#    'aaid': {'authenticatedState': 'authenticated',
#     'id': 'Oc',
#     'namespace': {'code': 'mdou'},
#     'primary': False,
#     'xid': 'EV'},
#    'acid': {'authenticatedState': 'ambiguous',
#     'id': 'RGoOoR',
#     'namespace': {'code': 'sdtMml2dK6'},
#     'primary': False,
#     'xid': 'eR'},
#    'adcloud': {'authenticatedState': 'ambiguous',
#     'id': 'arg4D21',
#     'namespace': {'code': '5xcVpnC'},
#     'primary': False,
#     'xid': 'Gsyq3FQ'},
#    'emailid': {'authenticatedState': 'loggedOut',
#     'id': 'KrR97',
#     'namespace': {'code': 'hjPoAE'},
#     'primary': False,
#     'xid': 'UA4FQWCDl'},
#    'mcid': {'authenticatedState': 'loggedOut',
#     'id': 'etX',
#     'namespace': {'code': 'cdg'},
#     'primary': False,
#     'xid': 'cFdy6R4XT'},
#    'phonenumberid': {'authenticatedState': 'authenticated',
#     'id': 'm8ZcWf',
#     'namespace': {'code': 'Fx3q35G'},
#     'primary': False,
#     'xid': '084ZNMece'},
#    'tntid': {'authenticatedState': 'loggedOut',
#     'id': 'ZbdXmpB',
#     'namespace': {'code': 'GMagm'},
#     'primary': False,
#     'xid': 'z9pYf0CSX'}}},
#  'environment': {'ISP': 'jDD0XY4y',
#   '_dc': {'language': 'en-US'},
#   'browserDetails': {'acceptLanguage': 'Ut5B',
#    'cookiesEnabled': False,
#    'javaEnabled': False,
#    'javaScriptEnabled': False,
#    'javaScriptVersion': '4R',
#    'javaVersion': 'NHTbW4pLy',
#    'name': 'fY',
#    'quicktimeVersion': 'NTj',
#    'thirdPartyCookiesEnabled': False,
#    'userAgent': 'N25oa',
#    'userAgentClientHints': {'architecture': 'Y7fGQpK',
#     'bitness': 'ceLkf1Uhbn',
#     'mobile': False,
#     'model': 'IrritlAzO',
#     'platform': 'BethSZ5',
#     'platformVersion': 'jhcH',
#     'wow64': False},
#    'vendor': 'Qilj',
#    'version': 'sQHnSwnU',
#    'viewportHeight': 7,
#    'viewportWidth': 4},
#   'carrier': 'ctdCj',
#   'colorDepth': 2,
#   'connectionType': 'mobile_lte',
#   'domain': 'zIMS1',
#   'duration': 15,
#   'ipV4': None,
#   'ipV6': None,
#   'operatingSystem': 'F5FObCgYd',
#   'operatingSystemVendor': 'YurIcJafTB',
#   'operatingSystemVersion': 'EWK',
#   'previousScreen': 'kg',
#   'type': 'application',
#   'viewedScreen': 'BtHM',
#   'viewportHeight': 11,
#   'viewportWidth': 11},
#  'marketing': {'campaignGroup': 'Lbr3',
#   'campaignName': 'HKdS',
#   'trackingCode': 'S3dmT'},
#  'media': {'mediaTimed': {'adCount': {'id': 'SLCyWyDOf',
#     'value': 37.63113556423394},
#    'averageMinuteAudience': {'id': 'MqK6uQDJFm', 'value': 51.9596770372362},
#    'chapterCount': {'id': '2KiH', 'value': 27.02895742059589},
#    'completes': {'id': 'eA', 'value': 0.9143367894295873},
#    'dayPart': 'HrMTcpm',
#    'dropBeforeStarts': {'id': 'JQACgiZmE', 'value': 13.205671218151787},
#    'estimatedStreams': {'id': 'jn5diu', 'value': 82.52187424270659},
#    'federated': {'id': 'a22ZKbQy', 'value': 30.390972295197606},
#    'idp': 'FOa6z',
#    'impressions': {'id': 'spapj', 'value': 10.726816865511408},
#    'mediaAuth': 'yNwD',
#    'mediaChapter': {'chapterAssetReference': {'_dc': {'title': 'i9UV'},
#      '_id': '30833564-cc59-4c3f-8062-8de9436c8dd3',
#      '_xmpDM': {'duration': 13}},
#     'chapterAssetViewDetails': {'index': 11, 'offset': 5},
#     'completes': {'id': 'zc7J', 'value': 13.427167998395548},
#     'downloadedPlayback': False,
#     'federated': {'id': 'gfSDi', 'value': 38.80058596734696},
#     'impressions': {'id': 'vh5PJf', 'value': 87.64338614766424},
#     'timePlayed': {'id': '33WklBS8NY', 'value': 60.21423729379605}},
#    'mediaSegmentViews': {'id': 'hws2', 'value': 48.83921488327695},
#    'pauseImpactedStreams': {'id': 'UJ', 'value': 56.45799305021526},
#    'pauseTime': {'id': 'oMBEo', 'value': 44.52262949111308},
#    'pauses': {'id': 'YJprTt', 'value': 28.973099694633177},
#    'playhead': 9,
#    'primaryAssetReference': {'Audio': {'_dc': {'creator': 'nX0bgk'},
#      '_id3': {'Audio': {'_id3': {'TPUB': 'ZvC', 'TRSN': 'R15'}}},
#      '_xmpDM': {'album': '7qog3R', 'artist': 'Br0'}},
#     '_dc': {'creator': 'HOy0dr7j7J', 'title': 'w1OEGB'},
#     '_id': 'f332db8f-69fd-4ddc-8b01-81c3f6d87fee',
#     '_id3': {'Audio': {'_id3': {'TPUB': 'u5', 'TRSN': '4X3x4g'}}},
#     '_iptc4xmpExt': {'Episode': {'_iptc4xmpExt': {'Identifier': 'https://www.jZUb8vCZC1.com',
#        'Name': 'ERDwJL2uv',
#        'Number': 47.16824467606253}},
#      'Season': {'_iptc4xmpExt': {'Identifier': 'https://www.T0IKPS3vrG.com',
#        'Name': '2mn',
#        'Number': 34.11953727682459}},
#      'Series': {'_iptc4xmpExt': {'Identifier': 'https://www.ecjsk2eNMJ.com',
#        'Name': '6BzxDUx3z'}}},
#     '_xmpDM': {'album': 'ePSt',
#      'artist': 'MJ',
#      'duration': 3,
#      'releaseDate': 'HSHEmOq'},
#     'firstAirDate': '4FFw',
#     'showType': 'oiRQcv',
#     'streamFormat': 'MAP1t9',
#     'streamType': 'video'},
#    'primaryAssetViewDetails': {'_id': '0be2cb19-2e4e-43bb-a7ec-96f577c96dda',
#     'adLoadType': 'TkxtaHRrs',
#     'broadcastChannel': 'hC6MlEF',
#     'broadcastContentType': 'UGC',
#     'broadcastNetwork': 'heuH',
#     'closeCaption': {'playerStateCount': 5,
#      'playerStateSet': False,
#      'playerStateTime': 7},
#     'downloadedPlayback': False,
#     'fullScreen': {'playerStateCount': 14,
#      'playerStateSet': False,
#      'playerStateTime': 16},
#     'inFocus': {'playerStateCount': 0,
#      'playerStateSet': False,
#      'playerStateTime': 16},
#     'mute': {'playerStateCount': 8,
#      'playerStateSet': False,
#      'playerStateTime': 18},
#     'path': 'RJSIH',
#     'pictureInPicture': {'playerStateCount': 20,
#      'playerStateSet': False,
#      'playerStateTime': 7},
#     'playerName': 'h0Lgvu9o',
#     'playerSDKVersion': {'environment': 'server',
#      'name': 'https://www.Z2ket0Sgpm.com',
#      'version': 'aHYZB4bMst'},
#     'qoe': {'bitrateAverage': {'id': '4vV', 'value': 44.965509425429374},
#      'bitrateAverageBucket': '9dLkglu1',
#      'bitrateChangeImpactedStreams': {'id': '8I96ZQum3U',
#       'value': 49.910413131117956},
#      'bitrateChanges': {'id': 'HB', 'value': 0.6068025156871171},
#      'bufferImpactedStreams': {'id': 'AJeoq', 'value': 59.94284489760924},
#      'bufferTime': {'id': 'ZVMLBQ', 'value': 61.46669894355468},
#      'buffers': {'id': 'EhAyE', 'value': 5.615241100059941},
#      'dropBeforeStarts': {'id': 'gaHnrk', 'value': 61.51154879850767},
#      'droppedFrameImpactedStreams': {'id': 'qXKWd9',
#       'value': 89.93655799621195},
#      'droppedFrames': {'id': 'rKA9', 'value': 81.93083833856572},
#      'error': {'errorID': 'KK', 'errorSource': 'external'},
#      'errorImpactedStreams': {'id': '6XPi', 'value': 2.387413177849944},
#      'errors': {'id': 'wDkxCqkLmc', 'value': 55.257221295954864},
#      'stallTime': {'id': 'ypH', 'value': 36.789812336116526},
#      'stallingImpactedStreams': {'id': 'KE', 'value': 51.94385047466216},
#      'stalls': {'id': 'WxtaOII', 'value': 40.4513458983854},
#      'timeToStart': {'id': 'qe', 'value': 28.692842557777954}},
#     'sessionTimeout': 5,
#     'sourceFeed': 'XBmpWDEtY',
#     'vhlVersion': 'K8pSyV2bPl'},
#    'progress10': {'id': '9pLx', 'value': 19.12213582029818},
#    'progress25': {'id': 'tk', 'value': 28.398244339098035},
#    'progress50': {'id': 'PGRHrA3F', 'value': 71.34274292252617},
#    'progress75': {'id': 'uTkIBFw', 'value': 51.03614701252426},
#    'progress95': {'id': 'VA2', 'value': 8.593579625450975},
#    'publisher': 'C9',
#    'radioStation': 'sPHzicOj',
#    'recordLabel': 'QvMP3Wm4',
#    'resumes': {'id': 'vz', 'value': 76.05821101250632},
#    'starts': {'id': 'j2qRm1R', 'value': 70.32995358784012},
#    'timePlayed': {'id': 'BitrO', 'value': 2.3589679418056377},
#    'totalTimePlayed': {'id': 'sxFcoTdtAw', 'value': 35.79670473632878},
#    'uniqueTimePlayed': {'id': 'ilnn3x0AY', 'value': 23.700977762961255}}},
#  'placeContext': {'POIinteraction': {'POIDetail': {'POIID': 'QvhXTe71n',
#     'beaconInteractionDetails': {'beaconMajor': 72.07296074845688,
#      'beaconMinor': 30.338240315469292,
#      'proximity': 'near',
#      'proximityUUID': 'OR9JbQyo'},
#     'category': 'hi8D2iH',
#     'distanceToPOICenter': 35.27544524168467,
#     'geoInteractionDetails': {'deviceGeoAccuracy': 17.666528664488663,
#      'distanceToCenter': 72.36360178457961,
#      'geoShape': {'_id': 'FJqY',
#       '_schema': {'circle': {'_id': '0aqjwO',
#         '_schema': {'coordinates': {'_id': '0bfc437b-d2fb-4c3b-8099-01418caf53ec',
#           '_schema': {'description': 'u4YZCY',
#            'elevation': 21.569725090983802,
#            'latitude': 80.19034036281664,
#            'longitude': 85.55228934221068}},
#          'description': 'W1',
#          'radius': 35.137322386690876}},
#        'description': 'rrV',
#        'elevation': 37.60101224387498},
#       'ceiling': 37.40337942982726}},
#     'locatingType': 'gps',
#     'metadata': {},
#     'name': 'sEaI',
#     'poiID': 'sAwN',
#     'type': 'kTTt'},
#    'poiDetail': {'POIID': '8Yv0kBjRf',
#     'beaconInteractionDetails': {'beaconMajor': 26.587036933895448,
#      'beaconMinor': 87.56971196225926,
#      'proximity': 'unknown',
#      'proximityUUID': 'ko'},
#     'category': 'Wwhagb',
#     'distanceToPOICenter': 18.900344970295446,
#     'geoInteractionDetails': {'deviceGeoAccuracy': 23.91887527554846,
#      'distanceToCenter': 61.20185956296734,
#      'geoShape': {'_id': 'Nff9yjw4',
#       '_schema': {'circle': {'_id': 'kyKcKoeOq',
#         '_schema': {'coordinates': {'_id': '371d83c6-3ddd-4e28-a8e5-11d86ecbdaad',
#           '_schema': {'description': 'oQAXieo',
#            'elevation': 69.37938556085365,
#            'latitude': 76.2052695419408,
#            'longitude': 26.68947877553608}},
#          'description': 'Wb',
#          'radius': 8.922969910794196}},
#        'description': 'tez8Qncu',
#        'elevation': 5.940398903584479},
#       'ceiling': 4.813012577257552}},
#     'locatingType': 'wifi-triangulation',
#     'metadata': {},
#     'name': '5LgdW5',
#     'poiID': 'MuAxWQYA',
#     'type': 'K0'},
#    'poiEntries': {'id': 'KvPC', 'value': 8.763886690638268},
#    'poiExits': {'id': 'LY9MaS3LBq', 'value': 14.353869588786912}},
#   'geo': {'_id': 'fef6ddcc-0ad2-4591-b40b-0bafe11e99cb',
#    '_schema': {'description': 'Pb',
#     'elevation': 22.384153490980424,
#     'latitude': 37.02883933517538,
#     'longitude': 34.06311662189713},
#    'city': '031az4Sigs',
#    'countryCode': 'VP',
#    'dmaID': 9,
#    'msaID': 17,
#    'postalCode': 'aRtH4er'},
#   'ianaTimezone': 'Ld',
#   'localTime': '2022-10-08T12:13:27.047907',
#   'localTimezoneOffset': 18},
#  'receivedTimestamp': '2022-10-05T11:06:27.047907',
#  'search': {'isPaid': False,
#   'keywords': '14ybAZN',
#   'pageDepth': 20,
#   'position': 8,
#   'searchEngine': 'PM4bQ',
#   'searchEngineID': 'https://www.f198pDdFcO.com',
#   'slot': 'top'},
#  'segmentMembership': None,
#  'userActivityRegion': {'captureTimestamp': '2022-09-30T02:00:21.047907',
#   'dataCenterLocation': 'VA6'},
#  'web': {'webInteraction': {'URL': 'Nq15S',
#    'linkClicks': {'id': 'PhckA', 'value': 81.2359605008404},
#    'name': 'e3M8OO',
#    'region': 'FFkwz',
#    'type': 'exit'},
#   'webPageDetails': {'URL': '6GVMWns5U',
#    'isErrorPage': False,
#    'isHomePage': False,
#    'name': 'GLOkAEQ1',
#    'pageViews': {'id': '9nggVxgt', 'value': 88.29039859502379},
#    'server': 'MIIV',
#    'siteSection': 'qjR1pO4q',
#    'viewName': '99m'},
#   'webReferrer': {'URL': 'PXCDSgOSC', 'type': 'usenet'}}}

# %%
event = create_xdm_event(analytics_ee_schema, user_id = "abc@adobe.com", event_type = "commerce.purchases", 
                         timestamp = datetime.now().isoformat(),
                        duplicates = [
                            ("web", "_experience/analytics/endUser/firstWeb"), 
                        ("web", "_experience/analytics/session/web"),
                        ("environment/operatingSystem", "_experience/analytics/customDimensions/eVars/eVar1"),
                        ("environment/viewedScreen", "_experience/analytics/customDimensions/eVars/eVar2"),
                        ("marketing/campaignGroup", "_experience/analytics/customDimensions/eVars/eVar3"),
                        ("placeContext/geo/city", "_experience/analytics/customDimensions/eVars/eVar4"),
                        ("placeContext/geo/countryCode", "_experience/analytics/customDimensions/eVars/eVar5"),
                        ("web/webInteraction/linkClicks/value", "_experience/analytics/event1to100/event1/value"),
                        ("web/webPageDetails/pageViews/value", "_experience/analytics/event1to100/event2/value"),
                        ("commerce/purchases/value", "_experience/analytics/event1to100/event3/value"),
                        ("commerce/productViews/value", "_experience/analytics/event1to100/event4/value"),
                        ("timestamp", "receivedTimestamp"),
                        ("timestamp", "userActivityRegion/captureTimestamp")],
                        overrides = [
                            ("web/webInteraction/linkClicks/value", 1.0)
                        ])

# %% [markdown]
# ### Count number of keys in experience event
# One interesting aspect of XDM data is that it dense, and contains a ton of data.
# Let's check the number of fields we've populated

# %%
import pandas as pd
#convert to pandas, which has nice json normalize
flat_dict = pd.json_normalize(event).to_dict(orient="records")[0]
print("Number of keys = ", len(flat_dict.keys()))
# Out:
# Number of keys =  3026

# %%
with open("example_event_indent_new.json", "w") as f:
    json.dump(event, f, indent=2)
with open("example_event_new.json", "w") as f:
    json.dump(event, f)

# %% [markdown]
# # Create a detailed simulation
#
# The next step is to create a more detailed simulation that will allow a reasonable propensity model to be built.
#
# Our goal in this task will be to create a propensity model for "subscription" events.
#
# A subscription event will be defined as an event where a `web.formFilledOut` event is recorded, with a specific
# These will be events where a customer subscribes to the

# %% [markdown]
# ## EventTypes and their contribution to propensity
#
# We will allow for several types of experience events to be received for each user.
# For each user, we will create a "generative" model of subscription as follows:
#
# 1. We sample randomly from a poisson distribution for the number of advertising impressions, webPageViews, emailsSent. **These events can happen at random times over a 10 week interval.**
# 2. For each of these "base" exposure events, we then have a corresponding conversion:
#     - If an advertising impression occurs, we then allow for an advertising click to happen, with a certain probability.
#     - If a web Page view occurs, then linkClicks, productViews, purchases, propositionDisplays, Interacts and Dismisses can all occur.
#     - For an Email Sent, opens and clicks can then also occur.
#
# 3. After all these base events have been generated, we then have a timeseries of events for each user. Each of the timeseries events affects the user's propensity to subscribe. After each event the user then has a certain probability of subscribing. The subscription is then evaluated with a Bernoulli draw - if the user subscribes, no further subscription evaluations are made. If the subscription does not happen, the subscription possibility will continue to be evaluated.
#
# 4. Extra - if more than 10 advertising impressions, or 5 emails are sent, the user churns, and no more events for that user are generated.

# %%
advertising_events = {
 
    #eventType          : (weeklyAverageOccurrence, propensityDelta, [(field_to_replace, value)], timeInHoursFromDependent)
    "advertising.clicks": (0.01,                    0.002,            [("advertising/clicks/value", 1.0)], 0.5) , 
    "advertising.impressions": (0.1, 0.001, [("advertising/impressions/value", 1.0)], 0),

    "web.webpagedetails.pageViews": (0.1, 0.005, [("web/webPageDetails/pageViews/value", 1.0)], 0.1),
    "web.webinteraction.linkClicks": (0.05, 0.005, [("web/webInteraction/linkClicks/value", 1.0)], 0.1),
   
    
    "commerce.productViews": (0.05, 0.005, [("commerce/productViews/value", 1.0)], 0.2),
    "commerce.purchases": (0.01, 0.1, [("commerce/purchases/value", 1.0)], 1),
    
    
    "decisioning.propositionDisplay": (0.05, 0.005, [("_experience/decisioning/propositionEventType/display", 1)], 0.1),
    "decisioning.propositionInteract": (0.01, 0.1, [("_experience/decisioning/propositionEventType/interact", 1)], 0.05),
    "decisioning.propositionDismiss": (0.01, -0.2, [("_experience/decisioning/propositionEventType/dismiss", 1)], 0.05),

    
    "directMarketing.emailOpened": (0.2, 0.02, [("directMarketing/opens/value", 1.0)], 24),
    "directMarketing.emailClicked": (0.05, 0.1, [("directMarketing/clicks/value", 1.0)], 0.5),
    "directMarketing.emailSent": (0.5, 0.005, [("directMarketing/sends/value", 1.0)], 0),
    
    "web.formFilledOut": (0.0, 0.0, [("web/webPageDetails/name", "subscriptionForm")], 0),

}

event_dependencies = {
    "advertising.impressions": ["advertising.clicks"],
    "directMarketing.emailSent": ["directMarketing.emailOpened"],
    "directMarketing.emailOpened": ["directMarketing.emailClicked"],
    "directMarketing.emailClicked": ["web.webpagedetails.pageViews"],
    "web.webpagedetails.pageViews": ["web.webinteraction.linkClicks", "commerce.productViews", "decisioning.propositionDisplay"],
    "commerce.productViews": ["commerce.purchases"],
    "decisioning.propositionDisplay": ["decisioning.propositionInteract", "decisioning.propositionDismiss"]
    
}

# %%
import numpy as np
from datetime import datetime
import math

N_USERS = 1000
FIRST_USER = 9000


N_WEEKS = 10
GLOBAL_START_DATE = datetime.now() - timedelta(weeks=12)
GLOBAL_END_DATE = GLOBAL_START_DATE + timedelta(weeks=N_WEEKS)

events = []
for user in range(N_USERS):
    user_id = FIRST_USER + user
    user_events = []
    base_events = {}
    for event_type in ["advertising.impressions", "web.webpagedetails.pageViews", "directMarketing.emailSent"]:
        n_events = np.random.poisson(advertising_events[event_type][0] * N_WEEKS)
        times = []
        for _ in range(n_events):
            times.append(random_date(GLOBAL_START_DATE, GLOBAL_END_DATE))
        
        base_events[event_type] = times
        
    for event_type, dependent_event_types in event_dependencies.items():
        
        if event_type in base_events:
            #for each originating event
            for event_time in base_events[event_type]:
                #Look for possible later on events
                for dependent_event in dependent_event_types:
                            n_events = np.random.poisson(advertising_events[dependent_event][0] * N_WEEKS)
                            times = []
                            for _ in range(n_events):
                                times.append(event_time + timedelta(hours = np.random.exponential(advertising_events[dependent_event][3])))
                            base_events[dependent_event] = times
        

    for event_type, times in base_events.items():
        for time in times:
            user_events.append({"userId": user_id, "eventType": event_type, "timestamp": time})
        
    user_events = sorted(user_events, key = lambda x: (x["userId"], x["timestamp"]))
    
   
    cumulative_probability = 0.001
    subscribed = False
    for event in user_events:
        cumulative_probability = min(1.0, max(cumulative_probability + advertising_events[event["eventType"]][1], 0))
        event["subscriptionPropensity"] = cumulative_probability
        if subscribed == False and "directMarketing" not in event["eventType"] and "advertising" not in event["eventType"]:
            subscribed = np.random.binomial(1, cumulative_probability) > 0
            if subscribed:
                subscriptiontime = event["timestamp"] + timedelta(seconds = 60)
                user_events.append({"userId": user_id, "eventType": "web.formFilledOut",  "timestamp": subscriptiontime})
        event["subscribed"] = subscribed
    user_events = sorted(user_events, key = lambda x: (x["userId"], x["timestamp"]))
           
    events = events + user_events

# %%
df = pd.DataFrame(events)


users_subscribing = df[df["subscribed"]]["userId"].unique()

print("Total Rows = ",len(df))

df[df["userId"] == users_subscribing[0]]
# Out:
# Total Rows =  10801
#     userId                      eventType                  timestamp  \
# 0     9000      directMarketing.emailSent 2022-08-03 16:32:37.231502
# 1     9000      directMarketing.emailSent 2022-08-05 12:09:59.231502
# 2     9000      directMarketing.emailSent 2022-08-19 17:17:59.231502
# 3     9000      directMarketing.emailSent 2022-08-26 01:45:06.231502
# 4     9000      directMarketing.emailSent 2022-09-03 15:57:23.231502
# 5     9000        advertising.impressions 2022-09-04 20:21:17.231502
# 6     9000      directMarketing.emailSent 2022-09-16 07:02:27.231502
# 7     9000      directMarketing.emailSent 2022-09-20 11:42:47.231502
# 8     9000      directMarketing.emailSent 2022-09-30 04:31:28.231502
# 9     9000    directMarketing.emailOpened 2022-09-30 23:13:10.873274
# 10    9000   directMarketing.emailClicked 2022-09-30 23:33:07.682872
# 11    9000   web.webpagedetails.pageViews 2022-09-30 23:35:45.588720
# 12    9000   web.webpagedetails.pageViews 2022-09-30 23:37:12.855325
# 13    9000  web.webinteraction.linkClicks 2022-09-30 23:37:31.064843
# 14    9000              web.formFilledOut 2022-09-30 23:38:31.064843
# 15    9000    directMarketing.emailOpened 2022-10-01 10:55:48.082928
#
#     subscriptionPropensity  subscribed
# 0                    0.006       False
# 1                    0.011       False
# 2                    0.016       False
# 3                    0.021       False
# 4                    0.026       False
# 5                    0.027       False
# 6                    0.032       False
# 7                    0.037       False
# 8                    0.042       False
# 9                    0.062       False
# 10                   0.162       False
# 11                   0.167       False
# 12                   0.172       False
# 13                   0.177        True
# 14                   0.197        True
# 15                   0.197        True

# %% [markdown]
# # Create XDM Data with simulation from above
#
# We now create the underlying XDM data from the simualtion above. We loop through events, and generate xdm events, storing these in an array that is written to a file.

# %%
with open("../resources/xdm_schema.json", "r") as f:
    analytics_ee_schema = json.load(f)



xdm_events = []


for event in sorted(events, key = lambda x: x["timestamp"]):    
    xdm_event = create_xdm_event(analytics_ee_schema, 
                                 user_id = f"synthetic-user-{event['userId']}@adobe.com", 
                                 event_type = event["eventType"], 
                                 timestamp = event["timestamp"].isoformat(),
                                duplicates = [
                                    ("web", "_experience/analytics/endUser/firstWeb"), 
                                ("web", "_experience/analytics/session/web"),
                                ("environment/operatingSystem", "_experience/analytics/customDimensions/eVars/eVar1"),
                                ("environment/viewedScreen", "_experience/analytics/customDimensions/eVars/eVar2"),
                                ("marketing/campaignGroup", "_experience/analytics/customDimensions/eVars/eVar3"),
                                ("placeContext/geo/city", "_experience/analytics/customDimensions/eVars/eVar4"),
                                ("placeContext/geo/countryCode", "_experience/analytics/customDimensions/eVars/eVar5"),
                                ("web/webInteraction/linkClicks/value", "_experience/analytics/event1to100/event1/value"),
                                ("web/webPageDetails/pageViews/value", "_experience/analytics/event1to100/event2/value"),
                                ("commerce/purchases/value", "_experience/analytics/event1to100/event3/value"),
                                ("commerce/productViews/value", "_experience/analytics/event1to100/event4/value"),
                                ("timestamp", "receivedTimestamp"),
                                ("timestamp", "userActivityRegion/captureTimestamp")],
                                overrides = advertising_events[event["eventType"]][2])
    xdm_events.append(xdm_event)

# %%
from typing import List, Dict
def write_rows_to_file(rows: List[Dict], outputfile: str, prefix="test-analytics-data") -> str:

    if outputfile is None:
        outputfile = f"{prefix}-{datetime.now().isoformat()}.json"

    json_data = [json.dumps(row) for row in rows]

    with open(outputfile, 'w') as f:
        f.write("\n".join(json_data))

    return outputfile

# %%
write_rows_to_file(xdm_events, outputfile=None)
# Out:
# 'test-analytics-data-2022-10-25T20:48:28.679200.json'
